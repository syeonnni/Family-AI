# %%
pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-tzwmqpc7
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-tzwmqpc7
#   Resolved https://github.com/facebookresearch/detectron2.git to commit c69939aa85460e8135f40bce908a6cddaa73065f
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from detectron2==0.6) (10.2.0)
# Requirement already satisfied: matplotlib in /home/encore/pytorch/venv/lib/python3.10/site-packages (from detectron2==0.6) (3.9.3)
# Collecting pycocotools>=2.0.2 (from detectron2==0.6)
#   Using cached pycocotools-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting termcolor>=1.1 (from detectron2==0.6)
#   Using cached termcolor-2.5.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting yacs>=0.1.8 (from detectron2==0.6)
#   Using cached yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Collecting tabulate (from detectron2==0.6)
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Collecting cloudpickle (from detectron2==0.6)
#   Using cached cloudpickle-3.1.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: tqdm>4.29.0 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from detectron2==0.6) (4.67.1)
# Collecting tensorboard (from detectron2==0.6)
#   Using cached tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Using cached fvcore-0.1.5.post20221221.tar.gz (50 kB)
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Using cached iopath-0.1.9-py3-none-any.whl.metadata (370 bytes)
# Collecting omegaconf<2.4,>=2.1 (from detectron2==0.6)
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting black (from detectron2==0.6)
#   Using cached black-24.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Requirement already satisfied: packaging in /home/encore/pytorch/venv/lib/python3.10/site-packages (from detectron2==0.6) (24.2)
# Requirement already satisfied: numpy in /home/encore/pytorch/venv/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (2.0.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.2)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core>=1.1->detectron2==0.6)
#   Using cached antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2==0.6)
#   Using cached portalocker-3.0.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from matplotlib->detectron2==0.6) (2.9.0.post0)
# Requirement already satisfied: click>=8.0.0 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from black->detectron2==0.6) (8.1.7)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2==0.6)
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2==0.6)
#   Using cached pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from black->detectron2==0.6) (4.3.6)
# Requirement already satisfied: tomli>=1.1.0 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from black->detectron2==0.6) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from black->detectron2==0.6) (4.12.2)
# Collecting absl-py>=0.4 (from tensorboard->detectron2==0.6)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard->detectron2==0.6)
#   Using cached grpcio-1.68.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting markdown>=2.6.8 (from tensorboard->detectron2==0.6)
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf!=4.24.0,>=3.19.6 (from tensorboard->detectron2==0.6)
#   Downloading protobuf-5.29.1-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (75.3.0)
# Requirement already satisfied: six>1.9 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from tensorboard->detectron2==0.6) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard->detectron2==0.6)
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard->detectron2==0.6)
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.5)
# Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# Using cached iopath-0.1.9-py3-none-any.whl (27 kB)
# Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Using cached pycocotools-2.0.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (427 kB)
# Using cached termcolor-2.5.0-py3-none-any.whl (7.8 kB)
# Using cached yacs-0.1.8-py3-none-any.whl (14 kB)
# Using cached black-24.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
# Using cached cloudpickle-3.1.0-py3-none-any.whl (22 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Using cached tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached grpcio-1.68.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
# Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Using cached pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading protobuf-5.29.1-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Using cached portalocker-3.0.0-py3-none-any.whl (19 kB)
# Building wheels for collected packages: detectron2, fvcore, antlr4-python3-runtime
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp310-cp310-linux_x86_64.whl size=905492 sha256=73070cbaf6fcf2974762054292e0809c5b68a61a47adfa857eab48db9b2a72f9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6l4nfck_/wheels/47/e5/15/94c80df2ba85500c5d76599cc307c0a7079d0e221bb6fc4375
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61398 sha256=d78da3fc28dc366e8e43caf044e8ed4eed1349f86ffdd2278a65d76c3e88739d
#   Stored in directory: /home/encore/.cache/pip/wheels/01/c0/af/77c1cf53a1be9e42a52b48e5af2169d40ec2e89f7362489dd0
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144556 sha256=2a8baa225f57980c1a1a52b28aab5b3e9fe0f0ff027e5e9ca4b4372349ddbd31
#   Stored in directory: /home/encore/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
# Successfully built detectron2 fvcore antlr4-python3-runtime
# Installing collected packages: antlr4-python3-runtime, yacs, werkzeug, termcolor, tensorboard-data-server, tabulate, protobuf, portalocker, pathspec, omegaconf, mypy-extensions, markdown, grpcio, cloudpickle, absl-py, tensorboard, iopath, hydra-core, black, pycocotools, fvcore, detectron2
# Successfully installed absl-py-2.1.0 antlr4-python3-runtime-4.9.3 black-24.10.0 cloudpickle-3.1.0 detectron2-0.6 fvcore-0.1.5.post20221221 grpcio-1.68.1 hydra-core-1.3.2 iopath-0.1.9 markdown-3.7 mypy-extensions-1.0.0 omegaconf-2.3.0 pathspec-0.12.1 portalocker-3.0.0 protobuf-5.29.1 pycocotools-2.0.8 tabulate-0.9.0 tensorboard-2.18.0 tensorboard-data-server-0.7.2 termcolor-2.5.0 werkzeug-3.1.3 yacs-0.1.8
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in /home/encore/pytorch/venv/lib/python3.10/site-packages (from opencv-python) (2.0.2)
# Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, detectron2
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random


# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %%
target = "./20241210image.jpg"
im = cv2.imread(target)

# %%
from IPython.display import Image

# 이미지 출력
display(Image(filename=target))

# %%
cfg = get_cfg()
cfg.MODEL.DEVICE = "cpu"
# add project-specific config (e.g., TensorMask) here if you're not running a model in detectron2's core library
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # set threshold for this model
# Find a model from detectron2's model zoo. You can use the https://dl.fbaipublicfiles... url as well
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
predictor = DefaultPredictor(cfg)
outputs = predictor(im)
# Out:
# [12/07 22:01:17 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# model_final_f10217.pkl: 178MB [00:01, 90.1MB/s]
# /home/encore/pytorch/venv/lib/python3.10/site-packages/torch/functional.py:534: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3595.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
v = Visualizer(im[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
out = v.draw_instance_predictions(outputs["instances"].to("cpu"))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30, 20))  

# out.get_image()에서 이미지 데이터를 가져옵니다.
image = out.get_image()

# 이미지 색상 순서를 BGR에서 RGB로 변경합니다.
image = image[:, :, ::-1]

# matplotlib을 사용하여 이미지를 출력합니다.
plt.imshow(image)
plt.axis('off')  # 축 숨기기
plt.show()
